# %%
import os
import re
import requests
import numpy as np
import pandas as pd

from tqdm import tqdm
from time import sleep
from random import randint
from bs4 import BeautifulSoup
from datetime import datetime

# %%
url = f"https://www.immonet.de/angebot/45932423?drop=sel&related=false&product=standard"
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
page = requests.get(url, headers=headers)
soup = BeautifulSoup(page.text, "html.parser")

# %%
panels_infos = soup.findAll('div', class_='row margin-top-18')

# %%
s = str(panels_infos[0])

# %%
if 'reference' in s:
    print(True)
# Out:
# True

# %%
re.findall('\d+.\d+,\d+.\d+', s)
# Out:
# ['51.164739482701606,6.881793101526019']

# %% [markdown]
# ## Teste REGEX - get lat long

# %%
df_ids = pd.read_csv('../data/all_offers_ids.csv')

# %%
df_ids.head()
# Out:
#    extraction_datetime  offer_id     city  city_code     type
# 0  2021-11-11 20:16:35  45559702  Dresden     100051  wohnung
# 1  2021-11-11 20:16:35  45740527  Dresden     100051  wohnung
# 2  2021-11-11 20:16:35  45738541  Dresden     100051  wohnung
# 3  2021-11-11 20:16:35  45695894  Dresden     100051  wohnung
# 4  2021-11-11 20:16:35  45891234  Dresden     100051  wohnung

# %%
for o_id in df_ids['offer_id'][:10]:

# %%
for o_id in df_ids['offer_id'][:10]:
    url = f"https://www.immonet.de/angebot/{o_id}?drop=sel&related=false&product=standard"
    headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
    page = requests.get(url, headers=headers)
    soup = BeautifulSoup(page.text, "html.parser")
    panels_infos = soup.findAll('div', class_='row margin-top-18')
    try:
        if 'reference' in str(panels_infos[0]):
            print(True)
            print(re.findall('\d+.\d+,\d+.\d+', str(panels_infos[0])))
    except:
        pass
# Out:
# True
# ['51.0718660588413,13.7446095705282']
# True
# ['51.0523793956666,13.729336990506']
# True
# ['51.000550131011764,13.837831448700937']
# True
# ['51.07922858128352,13.751453246077382']
# True
# ['51.09349024090944,13.721806412226147']
# True
# ['50.99776135389082,13.853262715225126']
# True
# ['51.0325238201334,13.725170828964']
# True
# ['51.010621173745776,13.767391909124926']
# True
# ['51.04573728236255,13.787696312671672']

# %%
panels_infos[1]
# Out:
# <div class="row margin-top-18">
# <div class="row list-100">
# <div class="col-xs-12 col-sm-6 list-30 text-180" id="pricename_2">
# 										Miete zzgl. NK</div>
# <div class="col-xs-12 col-sm-6 text-200" id="priceid_2">
# 										1450.0 €
# 											</div>
# </div>
# <div class="row list-100">
# <div class="col-xs-12 col-sm-6 list-30 text-95" id="pricename_4">
# 										Miete inkl. NK</div>
# <div class="col-xs-12 col-sm-6 text-100" id="priceid_4">
# 										1700.0 €
# 											</div>
# </div>
# <div class="row list-100">
# <div class="col-xs-12 col-sm-6 list-30 text-95" id="pricename_20">
# 										Nebenkosten</div>
# <div class="col-xs-12 col-sm-6 text-100" id="priceid_20">
# 										250.0 €
# 											</div>
# </div>
# <div class="row list-100">
# <div class="col-xs-12 col-sm-6 list-30 text-95">Heizkosten in Nebenkosten enthalten:</div>
# <div class="col-xs-12 col-sm-6 text-100" id="heatcostincludedStatus">Ja</div>
# </div>
# <div class="row list-100">
# ...

# %%
script_infos = soup.select('script', type_='text/javascript')

# %%
script_infos
# Out:
# [<script src="https://navigation.immonet.de/v1/FULL/195/navigation.js"></script>,
#  <script defer="" src="https://maps.googleapis.com/maps/api/js?key=AIzaSyAhKQ_dVVEM3riTDO4JDCB2ZSnkb8Iw6y8&amp;v=3.32.5a&amp;callback=initModalMap"></script>,
#  <script src="//cdnglobal.immonet.de/frontend-resources/5.21.3/lib/gmaps/gmaps.js"></script>,
#  <script src="//cdnglobal.immonet.de/frontend-resources/5.21.3/immonet/js/expose-head.min.js?v=187"></script>,
#  <script src="https://cdn-a.yieldlove.com/v2/yieldlove.js?immonet.de"></script>,
#  <script src="https://cdn.immonet.de/adtag-snippets/9.8.2/projects/expose.min.js"></script>,
#  <script type="text/javascript">
# ...
